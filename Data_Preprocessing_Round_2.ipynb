# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryPulley/Project_2/blob/Katie---Branch/Data_Preprocessing_Round_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import the dependencies

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Preprocess the census data

# %%
# Import the data for county census from xlsx
""" County Census Data that is 2020 to 2023 """
county_census_df = pd.read_csv('co-est2023-pop-updated - CO-EST2023-POP.csv', header=1)
county_census_df.head(15)
# Out:
#                     Geography         2020         2021         2022  \
# 0               United States  331,526,933  332,048,977  333,271,411
# 1    .Autauga County, Alabama       58,915       59,203       59,726
# 2    .Baldwin County, Alabama      233,227      239,439      246,531
# 3    .Barbour County, Alabama       24,969       24,533       24,700
# 4       .Bibb County, Alabama       22,188       22,359       21,986
# 5     .Blount County, Alabama       59,107       59,079       59,516
# 6    .Bullock County, Alabama       10,229       10,143       10,143
# 7     .Butler County, Alabama       19,025       18,890       18,668
# 8    .Calhoun County, Alabama      116,243      115,678      115,780
# 9   .Chambers County, Alabama       34,651       34,488       34,164
# 10  .Cherokee County, Alabama       24,969       25,074       25,353
# 11   .Chilton County, Alabama       45,057       45,259       45,848
# 12   .Choctaw County, Alabama       12,626       12,548       12,431
# 13    .Clarke County, Alabama       22,987       22,740       22,574
# 14      .Clay County, Alabama       14,212       14,170       14,183
#
#            2023
# 0   334,914,895
# 1        60,342
# 2       253,507
# 3        24,585
# 4        21,868
# 5        59,816
# 6         9,897
# 7        18,382
# 8       116,429
# 9        34,079
# 10       25,666
# 11       46,431
# 12       12,252
# 13       22,337
# 14       14,111

# %%
# Separate the "Geography" column by the comma to make 2 new columns "County" and "State"
county_census_df[["County", "State"]] = county_census_df["Geography"].str.split(",", n=1, expand=True)
county_census_df.head()
# Out:
#                   Geography         2020         2021         2022  \
# 0             United States  331,526,933  332,048,977  333,271,411
# 1  .Autauga County, Alabama       58,915       59,203       59,726
# 2  .Baldwin County, Alabama      233,227      239,439      246,531
# 3  .Barbour County, Alabama       24,969       24,533       24,700
# 4     .Bibb County, Alabama       22,188       22,359       21,986
#
#           2023           County     State
# 0  334,914,895    United States      None
# 1       60,342  .Autauga County   Alabama
# 2      253,507  .Baldwin County   Alabama
# 3       24,585  .Barbour County   Alabama
# 4       21,868     .Bibb County   Alabama

# %%
# Remove the "Geography" column from the county_census dataframe
county_census_df = county_census_df.drop(columns=["Geography"])
county_census_df.head()
# Out:
#           2020         2021         2022         2023           County  \
# 0  331,526,933  332,048,977  333,271,411  334,914,895    United States
# 1       58,915       59,203       59,726       60,342  .Autauga County
# 2      233,227      239,439      246,531      253,507  .Baldwin County
# 3       24,969       24,533       24,700       24,585  .Barbour County
# 4       22,188       22,359       21,986       21,868     .Bibb County
#
#       State
# 0      None
# 1   Alabama
# 2   Alabama
# 3   Alabama
# 4   Alabama

# %%
# Remove the "." from the front of each value in the "County" column
county_census_df["County"] = county_census_df["County"].str.lstrip(".")
county_census_df.head()
# Out:
#           2020         2021         2022         2023          County  \
# 0  331,526,933  332,048,977  333,271,411  334,914,895   United States
# 1       58,915       59,203       59,726       60,342  Autauga County
# 2      233,227      239,439      246,531      253,507  Baldwin County
# 3       24,969       24,533       24,700       24,585  Barbour County
# 4       22,188       22,359       21,986       21,868     Bibb County
#
#       State
# 0      None
# 1   Alabama
# 2   Alabama
# 3   Alabama
# 4   Alabama

# %%
# Reset the index of the county_census_df
county_census_df = county_census_df.reset_index(drop=True)
county_census_df.head()
# Out:
#           2020         2021         2022         2023          County  \
# 0  331,526,933  332,048,977  333,271,411  334,914,895   United States
# 1       58,915       59,203       59,726       60,342  Autauga County
# 2      233,227      239,439      246,531      253,507  Baldwin County
# 3       24,969       24,533       24,700       24,585  Barbour County
# 4       22,188       22,359       21,986       21,868     Bibb County
#
#       State
# 0      None
# 1   Alabama
# 2   Alabama
# 3   Alabama
# 4   Alabama

# %%
# Index the county_census_df by State
county_census_df = county_census_df.set_index("State")
county_census_df.head()
# Out:
#                  2020         2021         2022         2023          County
# State
# None      331,526,933  332,048,977  333,271,411  334,914,895   United States
#  Alabama       58,915       59,203       59,726       60,342  Autauga County
#  Alabama      233,227      239,439      246,531      253,507  Baldwin County
#  Alabama       24,969       24,533       24,700       24,585  Barbour County
#  Alabama       22,188       22,359       21,986       21,868     Bibb County

# %% [markdown]
# # Preprocess the Wild Birds Data

# %%
# Import the data for Wild birds
""" HPAI Data"""
wild_birds_df = pd.read_csv('hpai-wild-birds.csv')
wild_birds_df.head()
# Out:
#             State    County Collection Date Date Detected HPAI Strain  \
# 0  South Carolina  Colleton      12/30/2021     1/13/2022     EA H5N1
# 1  South Carolina  Colleton      12/30/2021     1/13/2022     EA H5N1
# 2  North Carolina      Hyde      12/30/2021     1/12/2022     EA H5N1
# 3  North Carolina      Hyde        1/8/2022     1/20/2022     EA H5N1
# 4  North Carolina      Hyde        1/8/2022     1/20/2022       EA H5
#
#         Bird Species WOAH Classification Sampling Method Submitting Agency
# 0    American wigeon           Wild bird  Hunter harvest              NWDP
# 1   Blue-winged teal           Wild bird  Hunter harvest              NWDP
# 2  Northern shoveler           Wild bird  Hunter harvest              NWDP
# 3    American wigeon           Wild bird  Hunter harvest              NWDP
# 4            Gadwall           Wild bird  Hunter harvest              NWDP

# %%
# Reset the index
wild_birds_df = wild_birds_df.reset_index(drop=True)
wild_birds_df.head()
# Out:
#             State    County Collection Date Date Detected HPAI Strain  \
# 0  South Carolina  Colleton      12/30/2021     1/13/2022     EA H5N1
# 1  South Carolina  Colleton      12/30/2021     1/13/2022     EA H5N1
# 2  North Carolina      Hyde      12/30/2021     1/12/2022     EA H5N1
# 3  North Carolina      Hyde        1/8/2022     1/20/2022     EA H5N1
# 4  North Carolina      Hyde        1/8/2022     1/20/2022       EA H5
#
#         Bird Species WOAH Classification Sampling Method Submitting Agency
# 0    American wigeon           Wild bird  Hunter harvest              NWDP
# 1   Blue-winged teal           Wild bird  Hunter harvest              NWDP
# 2  Northern shoveler           Wild bird  Hunter harvest              NWDP
# 3    American wigeon           Wild bird  Hunter harvest              NWDP
# 4            Gadwall           Wild bird  Hunter harvest              NWDP

# %%
# Index the county_census_df by State
wild_birds_df = wild_birds_df.set_index("State")
wild_birds_df.head()
# Out:
#                   County Collection Date Date Detected HPAI Strain  \
# State
# South Carolina  Colleton      12/30/2021     1/13/2022     EA H5N1
# South Carolina  Colleton      12/30/2021     1/13/2022     EA H5N1
# North Carolina      Hyde      12/30/2021     1/12/2022     EA H5N1
# North Carolina      Hyde        1/8/2022     1/20/2022     EA H5N1
# North Carolina      Hyde        1/8/2022     1/20/2022       EA H5
#
#                      Bird Species WOAH Classification Sampling Method  \
# State
# South Carolina    American wigeon           Wild bird  Hunter harvest
# South Carolina   Blue-winged teal           Wild bird  Hunter harvest
# North Carolina  Northern shoveler           Wild bird  Hunter harvest
# North Carolina    American wigeon           Wild bird  Hunter harvest
# North Carolina            Gadwall           Wild bird  Hunter harvest
#
#                Submitting Agency
# State
# South Carolina              NWDP
# South Carolina              NWDP
# North Carolina              NWDP
# North Carolina              NWDP
# North Carolina              NWDP

# %% [markdown]
# # Preprocess the Domestic Birds Data

# %%
# Import the data for Domestic birds
""" NEED SOURCE Data"""
domestic_birds_df = pd.read_csv('commercial-backyard-flocks - commercial-backyard-flocks.csv.csv')
domestic_birds_df.head()
# Out:
#         County           State Outbreak Date  \
# 0       Ottawa        Michigan    12-31-2024
# 1    Riverside      California    12-31-2024
# 2  Spartanburg  South Carolina    12-31-2024
# 3        Butte      California    12-31-2024
# 4        Miner    South Dakota    12-31-2024
#
#                             Flock Type  Flock Size
# 0          Commercial Turkey Meat Bird       29400
# 1           Commercial Table Egg Layer      181300
# 2  Commercial Upland Gamebird Producer         920
# 3                     WOAH Non-Poultry          70
# 4                         WOAH Poultry        1500

# %%
# Reset the index
domestic_birds_df = domestic_birds_df.reset_index(drop=True)
domestic_birds_df.head()
# Out:
#         County           State Outbreak Date  \
# 0       Ottawa        Michigan    12-31-2024
# 1    Riverside      California    12-31-2024
# 2  Spartanburg  South Carolina    12-31-2024
# 3        Butte      California    12-31-2024
# 4        Miner    South Dakota    12-31-2024
#
#                             Flock Type  Flock Size
# 0          Commercial Turkey Meat Bird       29400
# 1           Commercial Table Egg Layer      181300
# 2  Commercial Upland Gamebird Producer         920
# 3                     WOAH Non-Poultry          70
# 4                         WOAH Poultry        1500

# %%
# Index the dataframe by State
domestic_birds_df = domestic_birds_df.set_index("State")
domestic_birds_df.head()
# Out:
#                      County Outbreak Date  \
# State
# Michigan             Ottawa    12-31-2024
# California        Riverside    12-31-2024
# South Carolina  Spartanburg    12-31-2024
# California            Butte    12-31-2024
# South Dakota          Miner    12-31-2024
#
#                                          Flock Type  Flock Size
# State
# Michigan                Commercial Turkey Meat Bird       29400
# California               Commercial Table Egg Layer      181300
# South Carolina  Commercial Upland Gamebird Producer         920
# California                         WOAH Non-Poultry          70
# South Dakota                           WOAH Poultry        1500

# %%
# Rename "County Name" to "County"
domestic_birds_df = domestic_birds_df.rename(columns={"County Name": "County"})
domestic_birds_df.head()
# Out:
#                      County Outbreak Date  \
# State
# Michigan             Ottawa    12-31-2024
# California        Riverside    12-31-2024
# South Carolina  Spartanburg    12-31-2024
# California            Butte    12-31-2024
# South Dakota          Miner    12-31-2024
#
#                                          Flock Type  Flock Size
# State
# Michigan                Commercial Turkey Meat Bird       29400
# California               Commercial Table Egg Layer      181300
# South Carolina  Commercial Upland Gamebird Producer         920
# California                         WOAH Non-Poultry          70
# South Dakota                           WOAH Poultry        1500

# %% [markdown]
# # Create the Master Dataframe

# %%
# Reset the index for county_census
county_census_df = county_census_df.reset_index()
county_census_df
# Out:
#          State         2020         2021         2022         2023  \
# 0         None  331,526,933  332,048,977  333,271,411  334,914,895
# 1      Alabama       58,915       59,203       59,726       60,342
# 2      Alabama      233,227      239,439      246,531      253,507
# 3      Alabama       24,969       24,533       24,700       24,585
# 4      Alabama       22,188       22,359       21,986       21,868
# ...        ...          ...          ...          ...          ...
# 3140   Wyoming       42,197       41,626       41,374       41,249
# 3141   Wyoming       23,379       23,605       23,297       23,232
# 3142   Wyoming       20,457       20,681       20,727       20,745
# 3143   Wyoming        7,657        7,719        7,724        7,710
# 3144   Wyoming        6,816        6,746        6,858        6,808
#
#                  County
# 0         United States
# 1        Autauga County
# 2        Baldwin County
# 3        Barbour County
# 4           Bibb County
# ...                 ...
# 3140  Sweetwater County
# 3141       Teton County
# 3142       Uinta County
# 3143    Washakie County
# 3144      Weston County
#
# [3145 rows x 6 columns]

# %%
# Drop the first row of the dataframe
county_census_df = county_census_df.drop(0)
county_census_df
# Out:
#          State     2020     2021     2022     2023             County
# 1      Alabama   58,915   59,203   59,726   60,342     Autauga County
# 2      Alabama  233,227  239,439  246,531  253,507     Baldwin County
# 3      Alabama   24,969   24,533   24,700   24,585     Barbour County
# 4      Alabama   22,188   22,359   21,986   21,868        Bibb County
# 5      Alabama   59,107   59,079   59,516   59,816      Blount County
# ...        ...      ...      ...      ...      ...                ...
# 3140   Wyoming   42,197   41,626   41,374   41,249  Sweetwater County
# 3141   Wyoming   23,379   23,605   23,297   23,232       Teton County
# 3142   Wyoming   20,457   20,681   20,727   20,745       Uinta County
# 3143   Wyoming    7,657    7,719    7,724    7,710    Washakie County
# 3144   Wyoming    6,816    6,746    6,858    6,808      Weston County
#
# [3144 rows x 6 columns]

# %%
# For wild birds Dataframe, reset the index
wild_birds_df = wild_birds_df.reset_index()
wild_birds_df.head()
# Out:
#             State    County Collection Date Date Detected HPAI Strain  \
# 0  South Carolina  Colleton      12/30/2021     1/13/2022     EA H5N1
# 1  South Carolina  Colleton      12/30/2021     1/13/2022     EA H5N1
# 2  North Carolina      Hyde      12/30/2021     1/12/2022     EA H5N1
# 3  North Carolina      Hyde        1/8/2022     1/20/2022     EA H5N1
# 4  North Carolina      Hyde        1/8/2022     1/20/2022       EA H5
#
#         Bird Species WOAH Classification Sampling Method Submitting Agency
# 0    American wigeon           Wild bird  Hunter harvest              NWDP
# 1   Blue-winged teal           Wild bird  Hunter harvest              NWDP
# 2  Northern shoveler           Wild bird  Hunter harvest              NWDP
# 3    American wigeon           Wild bird  Hunter harvest              NWDP
# 4            Gadwall           Wild bird  Hunter harvest              NWDP

# %%
# For domestic birds Dataframe, reset the index
domestic_birds_df = domestic_birds_df.reset_index()
domestic_birds_df.head()
# Out:
#             State       County Outbreak Date  \
# 0        Michigan       Ottawa    12-31-2024
# 1      California    Riverside    12-31-2024
# 2  South Carolina  Spartanburg    12-31-2024
# 3      California        Butte    12-31-2024
# 4    South Dakota        Miner    12-31-2024
#
#                             Flock Type  Flock Size
# 0          Commercial Turkey Meat Bird       29400
# 1           Commercial Table Egg Layer      181300
# 2  Commercial Upland Gamebird Producer         920
# 3                     WOAH Non-Poultry          70
# 4                         WOAH Poultry        1500

# %%
# Combine all the 2 dataframes into 1 using "County" as the combining column
combined_df = pd.merge(county_census_df, wild_birds_df, on="County")
combined_df.head()
# Out:
#                  State_x     2020     2021     2022     2023  \
# 0   District of Columbia  670,839  669,037  670,949  678,972
# 1   District of Columbia  670,839  669,037  670,949  678,972
# 2   District of Columbia  670,839  669,037  670,949  678,972
# 3              Louisiana  142,834  146,121  148,056  150,145
# 4              Louisiana  160,111  158,866  157,704  157,568
#
#                  County    State_y Collection Date Date Detected HPAI Strain  \
# 0  District of Columbia         DC       5/25/2022      6/3/2022  EA/AM H5N1
# 1  District of Columbia         DC       5/25/2022      6/3/2022     EA H5N1
# 2  District of Columbia         DC      10/19/2022    10/25/2022     EA H5N1
# 3     Livingston Parish  Louisiana      11/21/2023     8/14/2024  EA/AM H5N1
# 4       Ouachita Parish  Louisiana      12/11/2023     8/14/2024  EA/AM H5N1
#
#              Bird Species WOAH Classification      Sampling Method  \
# 0                 Mallard           Wild bird  Morbidity/Mortality
# 1                 Mallard           Wild bird  Morbidity/Mortality
# 2  Warbler (unidentified)   Captive wild bird  Morbidity/Mortality
# 3            Canada goose           Wild bird  Morbidity/Mortality
# 4              Snow goose           Wild bird  Morbidity/Mortality
#
#                      Submitting Agency
# 0                             NPS/USGS
# 1                             NPS/USGS
# 2  Private (non-government) submission
# 3                                SCWDS
# 4                                SCWDS
